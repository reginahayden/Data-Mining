# %% [markdown]
# # Tugas 1

# %%
import pandas as pd
import numpy as np

# %%
# Menggabungkan dua data pada excell
data1=pd.read_csv("D:\Data Mining\kebakaran1.csv", sep=";")
data2 =pd.read_csv("D:\Data Mining\kebakaran2.csv", sep=";")
data_complete=pd.merge(data1,data2, on='month')
data_complete.head()
# Out:
#   month  day  FFMC   DMC    DC  ISI  temp  RH wind rain area
# 0   mar  fri  86,2  26,2  94,3  5,1   8,2  51  6,7    0    0
# 1   mar  fri  86,2  26,2  94,3    9   8,3  97    4  0,2    0
# 2   mar  fri  86,2  26,2  94,3  9,6  11,4  99  1,8    0    0
# 3   mar  fri  86,2  26,2  94,3  7,8  15,1  27  5,4    0    0
# 4   mar  fri  86,2  26,2  94,3  6,3  15,9  35    4    0    0

# %%
data_complete
# Out:
#       month  day  FFMC   DMC     DC   ISI  temp  RH wind rain   area
# 0       mar  fri  86,2  26,2   94,3   5,1   8,2  51  6,7    0      0
# 1       mar  fri  86,2  26,2   94,3     9   8,3  97    4  0,2      0
# 2       mar  fri  86,2  26,2   94,3   9,6  11,4  99  1,8    0      0
# 3       mar  fri  86,2  26,2   94,3   7,8  15,1  27  5,4    0      0
# 4       mar  fri  86,2  26,2   94,3   6,3  15,9  35    4    0      0
# 5       mar  fri  86,2  26,2   94,3   3,8  14,1  43  2,7    0      0
# 6       mar  fri  86,2  26,2   94,3   4,1  11,8  35  1,8    0      0
# 7       mar  fri  86,2  26,2   94,3     5    11  46  5,8    0      0
# 8       mar  fri  86,2  26,2   94,3   9,6  11,5  39  5,8    0      0
# 9       mar  fri  86,2  26,2   94,3   9,6   5,5  59  6,3    0      0
# 10      mar  fri  86,2  26,2   94,3     9  17,2  26  4,5    0      0
# 11      mar  fri  86,2  26,2   94,3  12,5  15,8  27  7,6    0      0
# 12      mar  fri  86,2  26,2   94,3     9  15,6  25  6,3    0      0
# ...

# %%
# Menyimpan excell langsung ke file
data_complete.to_csv("D:/Data Mining/data_kebakaran.csv")

# %%
data1
# Out:
#     month  day  FFMC    DMC     DC
# 0     mar  fri  86,2   26,2   94,3
# 1     oct  tue  90,6   35,4  669,1
# 2     oct  sat  90,6   43,7  686,9
# 3     mar  fri  91,7   33,3   77,5
# 4     mar  sun  89,3   51,3  102,2
# 5     aug  sun  92,3   85,3    488
# 6     aug  mon  92,3   88,9  495,6
# 7     aug  mon  91,5  145,4  608,2
# 8     sep  tue    91  129,5  692,6
# 9     sep  sat  92,5     88  698,6
# 10    sep  sat  92,5     88  698,6
# 11    sep  sat  92,8   73,2    713
# 12    aug  fri  63,5   70,8  665,3
# 13    sep  mon  90,9  126,5  686,5
# 14    sep  wed  92,9  133,3  699,6
# 15    sep  fri  93,3  141,2  713,9
# 16    mar  sat  91,7   35,8   80,8
# 17    oct  mon  84,9   32,8  664,2
# 18    mar  wed  89,2   27,9   70,8
# 19    apr  sat  86,3   27,4   97,1
# 20    sep  tue    91  129,5  692,6
# 21    sep  mon  91,8   78,5  724,3
# 22    jun  sun  94,3   96,3    200
# 23    aug  sat  90,2  110,9  537,4
# 24    aug  sat  93,5  139,4  594,2
# 25    aug  sun  91,4  142,4  601,4
# ...

# %%
data2
# Out:
#     month   ISI  temp  RH wind rain   area
# 0     mar   5,1   8,2  51  6,7    0      0
# 1     oct   6,7    18  33  0,9    0      0
# 2     oct   6,7  14,6  33  1,3    0      0
# 3     mar     9   8,3  97    4  0,2      0
# 4     mar   9,6  11,4  99  1,8    0      0
# 5     aug  14,7  22,2  29  5,4    0      0
# 6     aug   8,5  24,1  27  3,1    0      0
# 7     aug  10,7     8  86  2,2    0      0
# 8     sep     7  13,1  63  5,4    0      0
# 9     sep   7,1  22,8  40    4    0      0
# 10    sep   7,1  17,8  51  7,2    0      0
# 11    sep  22,6  19,3  38    4    0      0
# 12    aug   0,8    17  72  6,7    0      0
# 13    sep     7  21,3  42  2,2    0      0
# 14    sep   9,2  26,4  21  4,5    0      0
# 15    sep  13,9  22,9  44  5,4    0      0
# 16    mar   7,8  15,1  27  5,4    0      0
# 17    oct     3  16,7  47  4,9    0      0
# 18    mar   6,3  15,9  35    4    0      0
# 19    apr   5,1   9,3  44  4,5    0      0
# 20    sep     7  18,3  40  2,7    0      0
# ...
